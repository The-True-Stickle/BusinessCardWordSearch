# %% [markdown]
# Importing the necessary tools (using Python 3.13.2):
# - Pandas for making a dataframe to hold the potential words.
# - AyDictionary for getting the synonyms to test
# - Numpy for handling values like null

# %%
import pandas as pd
from AyDictionary import AyDictionary
import numpy as np

# %% [markdown]
# Now let's do a quick test to make sure the module is actually working (which sometimes it doesn't).

# %%
dictionary = AyDictionary()
synonyms = dictionary.synonym("computer")
print(f"Synonyms of 'card': {synonyms}")
print(len(synonyms))
# Out:
# Synonyms of 'card': ['website', 'disk cache', 'totalisator', 'data converter', 'computer peripheral', 'home computer', 'information processing system', 'storage', 'C.P.U.', 'web site', 'site', 'central processor', 'monitor', 'floppy', 'CPU', 'internet site', 'bus', 'client', 'keyboard', 'guest', 'computer accessory', 'computer storage', 'analog computer', 'number cruncher', 'computer circuit', 'computing machine', 'electronic computer', 'busbar', 'Turing machine', 'computer hardware', 'totalizer', 'microprocessor chip', 'silicon chip', 'data processor', 'host', 'totalizator', 'diskette', 'monitoring device', 'floppy disk', 'pari-mutuel machine', 'mainframe', 'memory board', 'central processing unit', 'predictor', 'machine', 'store', 'microchip', 'analogue computer', 'micro chip', 'totaliser', 'computer memory', 'node', 'peripheral device', 'server', 'processor', 'hardware', 'computing device', 'platform', 'chip', 'memory', 'CRT', 'cathode-ray tube', 'peripheral']
# 63

# %% [markdown]
# Since we know that dictionary is working (hopefully), let's create a list of interesting words we can branch out from. We can also make the word bank here which we'll use later.

# %%
interesting_words = {"hello", "howdy", "greetings", "bonjour", "hey", "salutation", 
                     "pleasantries", "respects", "programming", "computers", 
                     "epic", "awesome", "coaster", "thrill", "bombastic", "exciting",
                     "facinate", "profound", "curious", "hirable", "developer",
                     "design", "imagine", "think"}

#Initial word back of all six character word(s)
potential_word_bank = pd.DataFrame(columns=['word'])

#Data tracking variables for fun
num_checked_words = 0

# %% [markdown]
# Now here's the fun part. Time to collect every synonym of every interesting word which fits the criteria of either:
# - A word of six characters
# - A word with five characters (we can add an '!' to the end)
# - Two words which has six characters in total (with the space deleted)
# - Two words which has five characters in total (with the space deleted and a '!' added)

# %%
def filterWordBySize(word):
    if (len(word) <= 7) & (" " in word):
        if len(word) == 7:
            return word.replace(" ", "")
        elif len(word) == 6:
            return (word.replace(" ", "") + "!")
        else:
            return 'null'
    elif (len(word) == 6):
        return word
    elif (len(word) == 5):
        return (word + '!')
    else:
        return 'null'

#Let's test the function
print(filterWordBySize("Superb"))
print(filterWordBySize("Hello"))
print(filterWordBySize("smol"))
print(filterWordBySize("Hire me"))
print(filterWordBySize("Me too"))
print(filterWordBySize("To me"))

def addWordToWordBank(word):
    #potential_word_bank.iloc[len(potential_word_bank)] = [word, str(bin(ord(word[0]))), str(bin(ord(word[1]))), str(bin(ord(word[2]))), str(bin(ord(word[3]))), str(bin(ord(word[4]))), str(bin(ord(word[5])))]
    if (word not in potential_word_bank['word'].values) & isinstance(word, str):   
        potential_word_bank.loc[len(potential_word_bank)] = [word]

def checkWord(word):
    global num_checked_words 
    num_checked_words = num_checked_words + 1
    examined_word = filterWordBySize(word)
    if (examined_word != 'null') & (isinstance(examined_word, str)):
        #print(examined_word)
        addWordToWordBank(examined_word)
# Out:
# Superb
# Hello!
# null
# Hireme
# Metoo!
# null

# %%
for unique_word in interesting_words:
    #Get list of first layer synonyms
    if ' ' in unique_word:
        break
    synonyms = dictionary.synonym(unique_word)
    
    #For each first layer synonym
    if (synonyms == None):
        break
    for synonym_of_unique_word in synonyms:
        #Get list of second layer synonyms
        if ' ' in synonym_of_unique_word:
            break
        second_synonyms = dictionary.synonym(synonym_of_unique_word)
        #First check synonym itself
        checkWord(synonym_of_unique_word)
        #Then check all the synonyms of synonyms
        if second_synonyms == None:
            break
        for second_synonym_of_unique_word in second_synonyms:
            
            #Get list of third layer synonyms
            if ' ' in second_synonym_of_unique_word:
                break
            third_synonyms = dictionary.synonym(second_synonym_of_unique_word)
            
            #First check second synonym itself
            checkWord(second_synonym_of_unique_word)
            #Then check all synonyms of second synonyms
            if third_synonyms == None:
                break
            
            for third_synonym_of_unique_word in third_synonyms:
                checkWord(third_synonym_of_unique_word)
                        
potential_word_bank = potential_word_bank.dropna()
print(potential_word_bank['word'].unique())
print(len(potential_word_bank))
print (num_checked_words)
# Out:
# entertaining has no Synonyms in the API
# oratorical has no Synonyms in the API
# palatial has no Synonyms in the API
# startling has no Synonyms in the API
# intensified has no Synonyms in the API
# ['hullo!' 'hello!' 'howdy!' 'salute' 'credit' 'overdo' 'greet!' 'salaam'
#  'boast!' 'swash!' 'vaunt!' 'stater' 'tenant' 'towner' 'inmate' 'Asian!'
#  'Aussie' 'mortal' 'Latin!' 'person' 'liver!' 'equal!' 'being!' 'colony'
#  'payer!' 'lessee' 'lodger' 'roomer' 'renter' 'dream!' 'ideate' 'fancy!'
#  'image!' 'figure' 'think!' 'study!' 'musing' 'inset!' 'alter!' 'modify'
#  'change' 'enable' 'unify!' 'bestow' 'loose!' 'dizzy!' 'setup!' 'wakeup'
#  'ready!' 'mince!' 'better' 'vivify' 'muddy!' 'humble' 'shape!' 'lessen'
#  'touch!' 'empty!' 'inform' 'market' 'blunt!' 'impart' 'adjust' 'grace!'
#  'switch' 'delay!' 'rarefy' 'amend!' 'grime!' 'round!' 'dirty!' 'affect'
#  'still!' 'excite' 'beefup' 'sober!' 'morph!' 'colly!' 'shade!' 'refine'
#  'invert' 'tense!' 'bedim!' 'shoal!' 'crack!' 'patent' 'sauce!' 'untie!'
#  'mature' 'equate' 'minify' 'letup!' 'raise!' 'stain!' 'colour' 'ionate'
#  'supple' 'purge!' 'break!' 'blind!' 'purify' 'arouse' 'waken!' 'demist'
#  'charge' 'deaden' 'heatup' 'ossify' 'color!' 'fatten' 'retard' 'unfit!'
#  'debase' 'redact' 'darken' 'aerate' 'fasten' 'tender' 'loosen' 'subdue'
#  'impact' 'bubble' 'untune' 'proof!' 'blear!' 'clean!' 'rarify' 'relax!'
#  'cohere' 'dinge!' 'check!' 'ripen!' 'bemire' 'string' 'sexup!' 'bearon'
#  'rouse!' 'cloud!' 'nazify' 'fillup' 'spice!' 'extend' 'temper' 'unite!'
#  'clear!' 'widen!' 'commix' 'match!' 'shake!' 'expand' 'unsex!' 'easeup'
#  'deform' 'right!' 'gearup' 'alien!' 'shift!' 'reform' 'freeze' 'lower!'
#  'crush!' 'defog!' 'awaken' 'damage' 'adorn!' 'louden' 'chill!' 'speed!'
#  'dryout' 'soften' 'merge!' 'plump!' 'worsen' 'uglify' 'bring!' 'weaken'
#  'poison' 'spike!' 'chord!' 'buffer' 'update' 'harden' 'spoil!' 'cream!'
#  'soupup' 'hotup!' 'vagary' 'expiry' 'birth!' 'relief' 'easing' 'death!'
#  'heady!' 'fervor' 'spicy!' 'zesty!' 'savory' 'moving' 'aflare' 'mobile'
#  'blown!' 'motion' 'ahorse' 'wiggly' 'afoot!' 'flying' 'awheel' 'salty!'
#  'pursy!' 'large!' 'stuffy' 'fuggy!' 'close!' 'thrill' 'hasten' 'scoot!'
#  'flash!' 'barge!' 'shoot!' 'travel' 'propel' 'impel!' 'onset!' 'onrush'
#  'attack' 'eyelet' 'collar' 'instep' 'tongue' 'toecap' 'buskin' 'toebox'
#  'upper!' 'insole' 'felon!' 'outlaw' 'crook!' 'polar!' 'NSAID!' 'owlish'
#  'smell!' 'taste!' 'vision' 'odour!' 'sound!' 'ardor!' 'ardour' 'sexual'
#  'gender' 'sexed!' 'funny!' 'comic!' 'backup' 'growth' 'octet!' 'covey!'
#  'muster' 'septet' 'throng' 'quorum' 'course' 'floor!' 'table!' 'crowd!'
#  'bunch!' 'class!' 'sextet' 'rally!' 'triad!' 'grade!' 'suite!' 'block!'
#  'corpus' 'batch!' 'mound!' 'flora!' 'joblot' 'bundle' 'fleet!' 'galaxy'
#  'family' 'motley' 'botany' 'convoy' 'kludge' 'biota!' 'packet' 'clutch'
#  'Europe' 'fauna!' 'parcel' 'rummy!' 'exotic' 'gothic' 'quaint' 'freaky'
#  'crazy!' 'oddish' 'other!' 'eerie!' 'queer!' 'weird!' 'antic!' 'zombie'
#  'toddy!' 'zombi!' 'booze!' 'liquor' 'unique' 'insane' 'witty!' 'droll!'
#  'jocose' 'ironic' 'joking' 'bonzer' 'great!' 'awful!' 'grand!' 'unlike'
#  'divers' 'varied' 'manner' 'drape!' 'style!' 'idiom!' 'wonted' 'common'
#  'quirky' 'single' 'alone!' 'bulky!' 'rangy!' 'ample!' 'giant!' 'super!'
#  'heroic' 'double' 'jumbo!' 'macro!' 'larger' 'cosmic' 'bigger' 'hulky!'
#  'puffy!' 'broad!' 'depth!' 'heavy!' 'gangly' 'little' 'small!' 'length'
#  'tiptop' 'A-one!' 'rough!' 'craggy' 'scrap!' 'fight!' 'safety' 'clunk!'
#  'clump!' 'goodly' 'tumid!' 'manful' 'manly!' 'virile' 'thick!' 'width!'
#  'beamy!' 'erect!' 'putup!' 'build!' 'turgid' 'ornate' 'purple' 'poetic'
#  'noble!' 'water!' 'grume!' 'medium' 'fluid!' 'drink!' 'awing!' 'proud!'
#  'signal' 'lofty!' 'dread!' 'corked' 'horrid' 'rotten' 'rubber' 'lousy!'
#  'severe' 'worse!' 'corky!' 'crappy' 'tough!' 'worst!' 'shitty' 'uncool'
#  'pretty' 'sorry!' 'odious' 'aching' 'biting' 'bitter' 'galled' 'itchy!'
#  'chafed' 'answer' 'serve!' 'guilt!' 'repair' 'health' 'purity' 'atony!'
#  'state!' 'laxity' 'tilth!' 'mutism' 'demand' 'malady' 'frizz!' 'nudity'
#  'niche!' 'light!' 'status' 'place!' 'order!' 'atonia' 'danger' 'supply'
#  'issue!' 'layout' 'yield!' 'stock!' 'render' 'equip!' 'lease!' 'policy'
#  'grant!' 'denote' 'label!' 'ordain' 'decree' 'enact!' 'brand!' 'direct'
#  'hurry!' 'drive!' 'slice!' 'whang!' 'racket' 'volley' 'ground' 'carry!'
#  'triple' 'cannon' 'bunker' 'smash!' 'snick!' 'pitch!' 'shell!' 'bounce'
#  'shank!' 'rocket' 'launch' 'queue!' 'uprise' 'lineup' 'getup!' 'arise!'
#  'cause!' 'parlay' 'stake!' 'wager!' 'passby' 'glide!' 'angle!' 'ghost!'
#  'comeup' 'plough' 'weave!' 'trail!' 'breeze' 'return' 'gopast' 'stray!'
#  'billow' 'steam!' 'thread' 'career' 'motor!' 'beetle' 'float!' 'wheel!'
#  'whoosh' 'creep!' 'moveon' 'passon' 'tramp!' 'spread' 'lurch!' 'range!'
#  'drift!' 'shack!' 'circle' 'whine!' 'tread!' 'pursue' 'forge!' 'flock!'
#  'crank!' 'slide!' 'crawl!' 'swing!' 'cruise' 'ramble' 'retire' 'wander'
#  'spurt!' 'zigzag' 'jounce' 'spirt!' 'hurtle' 'follow' 'derail' 'whish!'
#  'ferry!' 'recede' 'moveup' 'resort' 'godown' 'ascend' 'lance!' 'whisk!'
#  'firing' 'strike' 'strafe' 'start!' 'curtsy' 'accost' 'herald' 'bowing'
#  'memory' 'honor!' 'award!' 'reward' 'lurid!' 'fierce' 'raging' 'savage'
#  'strong' 'stiff!' 'hefty!' 'brawny' 'rugged' 'robust' 'sinewy' 'bunchy']
# 560
# 6376

# %%
def getEightBitBinaryOfWord(word):
    return [format(ord(char), '08b') for char in word]

# %%
#Note: I know I could have set the original dataframe to the filtered version, but I wanted to show how the word bank was getting trimmed down without deleting the original dataframe for demonstration purposes.

#Lets first filter the words to ones which fulfills the top left corner
new_potential_word_bank_1 = potential_word_bank[potential_word_bank["word"].apply(lambda word: (getEightBitBinaryOfWord(word)[2])[0] == (getEightBitBinaryOfWord(word)[0])[0])]

#print(new_potential_word_bank_1)

#Now let's filter the words to ones which fulfills the top right corner
new_potential_word_bank_2 = new_potential_word_bank_1[new_potential_word_bank_1["word"].apply(lambda word: (getEightBitBinaryOfWord(word)[2])[7] == (getEightBitBinaryOfWord(word)[4])[0])]

#print(new_potential_word_bank_2)

#And now let's filter the words to ones which fulfills the bottom left corner
new_potential_word_bank_3 = new_potential_word_bank_2[new_potential_word_bank_2["word"].apply(lambda word: (getEightBitBinaryOfWord(word)[1])[7] == (getEightBitBinaryOfWord(word)[3])[0])]

#print(new_potential_word_bank_3)

#Finally let's filter the words to ones which fulfills the bottom right corner
new_potential_word_bank_4 = new_potential_word_bank_3[new_potential_word_bank_3["word"].apply(lambda word: (getEightBitBinaryOfWord(word)[3])[7] == (getEightBitBinaryOfWord(word)[5])[7])]
#print(new_potential_word_bank_4)

# %%
pd.set_option('display.max_rows', None)
display(new_potential_word_bank_4)
# Out:
#        word
# 38   alter!
# 58   inform
# 87   untie!
# 111  unfit!
# 122  untune
# 133  string
# 180  update
# 187  expiry
# 198  aflare
# 224  attack
# 232  upper!
# 245  ardor!
# 258  throng
# 298  other!
# 302  antic!
# 319  unlike
# 373  ornate
# 428  order!
# 468  uprise
# 487  stray!
# 537  strike
# 538  strafe
# 552  strong

# %%
#Finally, let's save the word bank to a csv file for future use
new_potential_word_bank_4.to_csv("potential_word_bank.csv", index=False)
